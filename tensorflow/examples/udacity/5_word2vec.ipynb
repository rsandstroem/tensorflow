# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.135208
# Nearest to nine: destroy, humps, catv, glenda, accented, fencing, mervyn, create,
# Nearest to that: landlocked, eithne, flamebait, opportunities, messages, bat, affiliated, hbo,
# Nearest to into: heavily, cavalier, solemnity, saxon, derivative, armadillos, congenital, universally,
# Nearest to one: brin, observations, tobit, overcome, glad, cooks, jordanes, duval,
# Nearest to six: devastation, dyke, ana, nejd, dining, araki, tapestry, criticisms,
# Nearest to time: spaulding, materiel, ballads, abdul, cheerfully, comit, exegetical, gaulish,
# Nearest to used: opt, ecu, wed, tasmania, traumatic, reasoning, shaken, topologically,
# Nearest to from: henrietta, reaffirm, recreated, gower, revolutionary, lipoproteins, gamma, mouthpiece,
# Nearest to united: entre, hitchhikers, gorges, twists, anesthetic, qumran, repopulated, predator,
# Nearest to all: correction, ovary, fuji, heater, morgue, frud, reparation, psychoactive,
# Nearest to are: moorland, hollis, readings, cement, homomorphisms, crabbe, conversions, trochaic,
# Nearest to to: mobygames, doublespeak, fijian, innocence, gaeilge, figueres, fringes, tolerance,
# Nearest to have: yauch, maryam, credo, spins, severed, illiteracy, electrification, inferior,
# Nearest to five: lara, tcp, paradoxes, allafrica, stored, hiawatha, kickboxing, shafi,
# Nearest to history: relativism, futhark, glut, laughing, latgale, thales, holyoke, brockhaus,
# Nearest to but: kayaking, metroid, linkin, lughnasadh, denmark, assay, redman, imitating,
# Average loss at step 2000: 4.357423
# Average loss at step 4000: 3.858273
# Average loss at step 6000: 3.789107
# Average loss at step 8000: 3.681863
# Average loss at step 10000: 3.615565
# Nearest to nine: eight, six, five, seven, zero, four, three, two,
# Nearest to that: which, it, sabrina, sachs, during, also, this, locarno,
# Nearest to into: laureates, from, saxon, universally, lud, johansson, cavalier, with,
# Nearest to one: two, three, four, six, eight, seven, five, nine,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to time: acquiescence, exegetical, curricula, survives, gettysburg, abdul, gaulish, materiel,
# Nearest to used: topologically, opt, traumatic, seen, tasmania, bled, broadband, shaken,
# Nearest to from: in, dreamed, through, into, by, restaurants, libido, within,
# Nearest to united: gorges, unitary, hitchhikers, predator, around, twists, psychoanalytic, entre,
# Nearest to all: heater, russa, afonso, psychoactive, several, correction, fuji, comparably,
# Nearest to are: were, is, tijuana, mikl, have, plissken, conversions, although,
# Nearest to to: gaeilge, would, not, helpdesk, louvain, transclusion, during, spreading,
# Nearest to have: had, be, has, are, yauch, do, cowl, lucrative,
# Nearest to five: six, eight, nine, four, seven, zero, three, two,
# Nearest to history: laughing, starfish, jethro, relativism, crowding, futhark, third, sprinter,
# Nearest to but: landless, sama, full, gathers, rouen, what, and, knute,
# Average loss at step 12000: 3.603459
# Average loss at step 14000: 3.576980
# Average loss at step 16000: 3.408523
# Average loss at step 18000: 3.458025
# Average loss at step 20000: 3.540238
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to that: which, however, but, underscore, libels, this, sabrina, klein,
# Nearest to into: from, across, laureates, universally, with, lud, through, additives,
# Nearest to one: two, four, seven, six, three, eight, five, nine,
# Nearest to six: four, eight, seven, nine, five, three, zero, two,
# Nearest to time: acquiescence, gettysburg, survives, ugle, materiel, ascends, benzodiazepine, way,
# Nearest to used: opt, topologically, seen, traumatic, known, referred, ursidae, brooms,
# Nearest to from: into, through, at, between, in, for, under, pani,
# Nearest to united: around, unitary, gorges, psychoanalytic, peripherals, improvised, red, magnetic,
# Nearest to all: these, many, psychoactive, several, parts, some, musicals, belligerent,
# Nearest to are: were, is, tijuana, have, mikl, apostolic, plissken, although,
# Nearest to to: gaeilge, would, not, brotherly, britten, louvain, himalayan, will,
# Nearest to have: had, has, be, are, were, do, yauch, according,
# Nearest to five: four, six, seven, eight, three, two, zero, nine,
# Nearest to history: laughing, crowding, rahul, starfish, slander, hundreds, futhark, jethro,
# Nearest to but: however, and, will, counterrevolutionary, which, landless, though, vilhelm,
# Average loss at step 22000: 3.499804
# Average loss at step 24000: 3.486711
# Average loss at step 26000: 3.482127
# Average loss at step 28000: 3.481831
# Average loss at step 30000: 3.502799
# Nearest to nine: eight, seven, six, four, five, three, two, zero,
# Nearest to that: which, this, where, but, however, sabrina, what, klein,
# Nearest to into: from, through, across, within, laureates, under, lud, malm,
# Nearest to one: two, seven, four, eight, six, three, five, nine,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to time: survives, way, year, achieves, republik, rye, acquiescence, xxxi,
# Nearest to used: known, seen, written, found, opt, considered, topologically, brooms,
# Nearest to from: into, through, under, after, libido, between, in, against,
# Nearest to united: unitary, gorges, psychoanalytic, magnetic, peripherals, qumran, savvy, improvised,
# Nearest to all: these, psychoactive, many, several, some, musicals, belligerent, any,
# Nearest to are: were, have, is, these, include, although, be, headwaters,
# Nearest to to: would, gaeilge, cannot, can, will, brotherly, not, louvain,
# Nearest to have: had, has, are, be, were, do, include, powdered,
# Nearest to five: four, seven, eight, three, six, zero, nine, two,
# Nearest to history: laughing, rahul, commencement, third, jethro, mechanical, crowding, sprinter,
# Nearest to but: however, though, and, although, sama, wacky, that, or,
# Average loss at step 32000: 3.500463
# Average loss at step 34000: 3.493832
# Average loss at step 36000: 3.454118
# Average loss at step 38000: 3.307720
# Average loss at step 40000: 3.427727
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to that: which, what, this, where, however, rapture, it, who,
# Nearest to into: from, through, universally, laureates, across, olivier, additives, malm,
# Nearest to one: seven, four, eight, six, two, five, three, nine,
# Nearest to six: five, seven, four, eight, three, nine, two, one,
# Nearest to time: way, year, astronauts, achieves, maluku, nikolai, acquiescence, years,
# Nearest to used: known, found, seen, written, considered, referred, given, traumatic,
# Nearest to from: through, into, libido, under, in, dulcimer, of, between,
# Nearest to united: psychoanalytic, unitary, gorges, southern, foobar, qumran, savvy, peripherals,
# Nearest to all: both, psychoactive, these, several, many, belligerent, crudely, preoccupied,
# Nearest to are: were, have, is, include, tijuana, be, cplp, riddler,
# Nearest to to: swami, will, louvain, cannot, can, gaeilge, could, and,
# Nearest to have: had, has, were, are, be, include, pledged, powdered,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to history: laughing, commencement, rahul, krulak, price, dunk, sprinter, leicestershire,
# Nearest to but: however, though, and, expend, although, it, which, wacky,
# Average loss at step 42000: 3.434593
# Average loss at step 44000: 3.459413
# Average loss at step 46000: 3.448767
# Average loss at step 48000: 3.357866
# Average loss at step 50000: 3.385218
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to that: which, however, what, this, but, where, tca, rapture,
# Nearest to into: from, through, additives, across, saxon, upon, within, solemnity,
# Nearest to one: six, eight, two, four, seven, nine, five, three,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to time: way, year, years, product, country, survives, maluku, communicating,
# Nearest to used: known, seen, found, referred, written, considered, given, available,
# Nearest to from: into, through, under, in, dulcimer, during, libido, within,
# Nearest to united: psychoanalytic, southern, australian, qumran, foobar, elfin, savvy, gorges,
# Nearest to all: both, these, belligerent, many, psychoactive, several, goryeo, deadpan,
# Nearest to are: were, is, have, minkowski, be, was, these, tijuana,
# Nearest to to: would, gabal, toward, could, brotherly, gaeilge, will, should,
# Nearest to have: had, has, were, be, are, according, having, who,
# Nearest to five: six, seven, four, eight, zero, nine, three, two,
# Nearest to history: machinations, phillies, actuarial, dunk, laughing, league, mechanical, ancient,
# Nearest to but: however, though, although, and, while, when, expend, that,
# Average loss at step 52000: 3.436725
# Average loss at step 54000: 3.429837
# Average loss at step 56000: 3.440326
# Average loss at step 58000: 3.398690
# Average loss at step 60000: 3.395157
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to that: which, what, however, this, tca, there, underscore, it,
# Nearest to into: from, through, across, within, under, around, over, additives,
# Nearest to one: two, seven, eight, five, four, nine, six, three,
# Nearest to six: four, eight, five, nine, seven, three, zero, two,
# Nearest to time: year, way, product, week, mesozoic, mishneh, period, case,
# Nearest to used: known, written, considered, seen, found, referred, available, described,
# Nearest to from: into, through, under, in, within, libido, dulcimer, between,
# Nearest to united: psychoanalytic, beginning, savvy, foobar, alvarez, southern, qumran, jarom,
# Nearest to all: both, many, these, those, any, every, multiple, several,
# Nearest to are: were, have, is, including, include, tijuana, minkowski, unsatisfied,
# Nearest to to: would, gabal, brahms, will, brotherly, mascarenes, gaeilge, worldcom,
# Nearest to have: has, had, are, were, include, be, erroneously, having,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to history: krulak, actuarial, period, connemara, center, demographics, machinations, gaza,
# Nearest to but: however, although, though, and, than, when, while, falsifiable,
# Average loss at step 62000: 3.237448
# Average loss at step 64000: 3.256206
# Average loss at step 66000: 3.401387
# Average loss at step 68000: 3.392882
# Average loss at step 70000: 3.357157
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to that: which, however, this, what, but, tca, usually, generally,
# Nearest to into: from, through, across, within, alibi, solemnity, additives, mouthpieces,
# Nearest to one: two, seven, six, eight, four, five, nine, three,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to time: year, way, product, oversees, process, eberhard, rosenberg, week,
# Nearest to used: known, written, found, seen, available, considered, cited, referred,
# Nearest to from: into, through, libido, during, dulcimer, by, in, under,
# Nearest to united: beginning, foobar, savvy, psychoanalytic, australian, following, insanity, beac,
# Nearest to all: many, both, several, every, psychoactive, multiple, some, these,
# Nearest to are: were, is, have, include, these, including, minkowski, be,
# Nearest to to: will, can, cannot, could, gabal, must, louvain, would,
# Nearest to have: had, has, are, were, include, be, erroneously, having,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to history: period, actuarial, list, demographics, fathoms, krulak, connemara, machinations,
# Nearest to but: however, although, though, which, that, while, and, olivine,
# Average loss at step 72000: 3.375760
# Average loss at step 74000: 3.353467
# Average loss at step 76000: 3.315004
# Average loss at step 78000: 3.350228
# Average loss at step 80000: 3.380289
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to that: which, however, where, rapture, this, underscore, mmol, grandsons,
# Nearest to into: from, through, across, within, beyond, over, additives, saxon,
# Nearest to one: six, seven, two, eight, four, three, five, nine,
# Nearest to six: four, five, seven, eight, three, nine, two, one,
# Nearest to time: year, way, eberhard, suzerainty, ascends, series, achieves, gettysburg,
# Nearest to used: known, referred, written, found, seen, available, described, given,
# Nearest to from: through, into, between, libido, in, rankings, after, novelette,
# Nearest to united: beginning, savvy, foobar, redrawn, australian, psychoanalytic, following, elbridge,
# Nearest to all: both, every, several, many, multiple, any, these, hockey,
# Nearest to are: were, have, is, include, although, those, minkowski, tijuana,
# Nearest to to: gaeilge, himalayan, would, louvain, will, gabal, brotherly, crucified,
# Nearest to have: had, has, are, include, be, were, having, erroneously,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to history: list, journal, krulak, actuarial, inker, fathoms, tennessee, databases,
# Nearest to but: however, although, while, which, though, and, see, than,
# Average loss at step 82000: 3.408593
# Average loss at step 84000: 3.409264
# Average loss at step 86000: 3.391281
# Average loss at step 88000: 3.354812
# Average loss at step 90000: 3.365960
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to that: which, however, but, what, tca, where, mmol, underscore,
# Nearest to into: from, through, across, with, additives, laureates, saxon, around,
# Nearest to one: seven, four, two, eight, five, six, three, nine,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to time: year, achieves, before, eberhard, gettysburg, quarter, suzerainty, notice,
# Nearest to used: known, referred, seen, written, given, described, found, called,
# Nearest to from: through, into, between, during, under, libido, across, torque,
# Nearest to united: beginning, foobar, savvy, following, redrawn, southern, australian, elbridge,
# Nearest to all: both, every, many, several, multiple, those, deadpan, each,
# Nearest to are: were, is, have, although, include, these, tijuana, minkowski,
# Nearest to to: towards, gaeilge, crucified, will, would, brotherly, louvain, upload,
# Nearest to have: had, has, were, be, having, are, include, erroneously,
# Nearest to five: seven, eight, four, six, three, nine, two, zero,
# Nearest to history: list, journal, krulak, actuarial, cgi, noree, period, demographics,
# Nearest to but: however, although, and, that, while, though, which, woolen,
# Average loss at step 92000: 3.398440
# Average loss at step 94000: 3.252237
# Average loss at step 96000: 3.360589
# Average loss at step 98000: 3.242013
# Average loss at step 100000: 3.355486
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to that: which, however, what, where, mmol, who, but, this,
# Nearest to into: through, from, across, within, over, out, additives, up,
# Nearest to one: four, two, seven, five, eight, three, nine, six,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to time: year, communicating, notice, attains, way, week, quarter, achieves,
# Nearest to used: known, written, referred, found, considered, seen, described, designed,
# Nearest to from: into, through, in, during, between, libido, within, dulcimer,
# Nearest to united: beginning, foobar, savvy, following, elbridge, redrawn, southern, australian,
# Nearest to all: many, every, both, several, these, multiple, those, any,
# Nearest to are: were, have, include, be, is, those, although, these,
# Nearest to to: will, could, would, gabal, can, should, must, cannot,
# Nearest to have: had, has, were, include, are, be, provide, tend,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to history: list, journal, cgi, krulak, actuarial, eldest, comecon, demographics,
# Nearest to but: however, although, though, and, while, which, that, where,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
import itertools
data_index = 0

def generate_batch_CBOW(batch_size, num_skips, skip_window):
  '''
  batch should be a shape of (batch_size, num_skips)
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
  '''  
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # double ended queue
    
  # collect the data into a buffer array
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # use itertools to filter out the central word from the bag
    mask = np.ones(span)
    mask[skip_window] = 0
    batch[i, :] = list(itertools.compress(buffer, mask))
    labels[i, 0] = buffer[skip_window] 
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print (embed)
  embed = tf.reduce_sum(embed, reduction_indices=1)
  print (embed)
  #embed = tf.zeros([batch_size, embedding_size])
  #for j in range(num_skips):
  #  embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 2, 128), dtype=float32, device=/device:CPU:0)
# Tensor("Sum:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.095450
# Nearest to no: pygmalion, linspire, abba, hezbollah, kinsman, intercession, renewable, fellowships,
# Nearest to such: compaq, deleted, imagines, libri, devises, minima, afghans, volante,
# Nearest to i: intel, tyrosine, unomig, feedstock, indexed, provincias, altruists, leno,
# Nearest to not: welch, serpents, sahib, phonological, reparation, pnp, perfectly, bach,
# Nearest to had: apoptosis, vectors, knew, shrinking, staunch, speciation, daugavpils, sedimentation,
# Nearest to may: facie, paradigms, fifths, mcclory, rancid, windsurfing, arbitral, kohanim,
# Nearest to than: litchfield, sanctuaries, tlp, pulses, last, eastwards, addressable, copying,
# Nearest to was: marko, cet, seam, relegation, olson, aesthetics, modulo, scorpion,
# Nearest to seven: prepare, rhetoric, empowered, berg, quito, acosta, haldeman, besiege,
# Nearest to most: gosford, slander, advantageous, maple, clinker, addiction, hieroglyphics, philologists,
# Nearest to are: bullion, culloden, multicellular, didactic, blessing, hin, liquidated, mata,
# Nearest to only: seidel, foederati, scissors, chambre, contractors, competencies, heapsort, spaced,
# Nearest to would: superpower, spells, governed, heights, nucleosynthesis, dawn, romans, liaison,
# Nearest to while: sumo, hypomania, immensely, factions, marsilio, tb, imprecise, logbook,
# Nearest to people: akihito, sepulchre, fast, descriptors, gygax, worldcon, now, formally,
# Nearest to used: beijing, patmos, arabians, malvales, volcanoes, eisa, tsu, autumn,
# Average loss at step 2000: 4.083701
# Average loss at step 4000: 3.559259
# Average loss at step 6000: 3.386155
# Average loss at step 8000: 3.236182
# Average loss at step 10000: 3.175248
# Nearest to no: publicise, a, pygmalion, abba, ditka, aztecs, asymmetric, arrigo,
# Nearest to such: known, well, luxuriant, imagines, riot, conde, realistic, kidman,
# Nearest to i: netsplit, osu, carbines, feedstock, ethnological, procurator, rowena, partially,
# Nearest to not: tov, also, never, often, still, har, ethicists, you,
# Nearest to had: have, has, was, were, operationally, having, envious, bukovina,
# Nearest to may: can, could, would, must, will, cannot, armas, might,
# Nearest to than: litchfield, eastwards, sanctuaries, or, tlp, copying, like, dionysius,
# Nearest to was: is, has, had, were, iterations, are, be, stagnant,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to most: more, adherents, horsepower, many, frontage, advantageous, addiction, grill,
# Nearest to are: were, is, have, was, bullion, multicellular, badajoz, martel,
# Nearest to only: heapsort, volga, pancakes, steed, anaheim, famously, scissors, transformed,
# Nearest to would: can, could, will, may, should, must, shoah, to,
# Nearest to while: factions, banque, among, logbook, sumo, imprecise, comorian, does,
# Nearest to people: mckenna, those, sepulchre, lewes, soles, pests, essence, excise,
# Nearest to used: beijing, known, buttstock, prick, eisa, utterly, crabs, heeded,
# Average loss at step 12000: 3.201944
# Average loss at step 14000: 3.156715
# Average loss at step 16000: 3.183874
# Average loss at step 18000: 3.121714
# Average loss at step 20000: 2.987285
# Nearest to no: a, any, ium, asymmetric, smolensk, intension, tubes, iadb,
# Nearest to such: well, known, these, luxuriant, follows, gabaa, realistic, chupacabras,
# Nearest to i: we, ii, you, iii, ethnological, g, t, he,
# Nearest to not: still, never, also, often, sometimes, almost, generally, har,
# Nearest to had: has, have, was, were, bukovina, having, pet, signalling,
# Nearest to may: can, could, would, will, must, might, should, cannot,
# Nearest to than: or, eastwards, litchfield, sanctuaries, avidly, much, disturbances, and,
# Nearest to was: is, had, were, has, iterations, became, pet, when,
# Nearest to seven: six, eight, nine, five, three, four, zero, two,
# Nearest to most: more, many, some, particularly, addiction, secluded, use, dilated,
# Nearest to are: were, is, have, blessing, include, orlogsflag, hler, interbreed,
# Nearest to only: heapsort, steed, cybernetic, volga, famously, fairgrounds, boomed, drawings,
# Nearest to would: will, can, could, may, should, must, might, cannot,
# Nearest to while: although, but, and, when, among, however, where, before,
# Nearest to people: those, pests, jews, mckenna, countries, paws, sepulchre, downward,
# Nearest to used: known, beijing, buttstock, considered, held, found, written, referred,
# Average loss at step 22000: 3.071880
# Average loss at step 24000: 3.040070
# Average loss at step 26000: 2.995672
# Average loss at step 28000: 3.024090
# Average loss at step 30000: 3.004915
# Nearest to no: any, lipids, iadb, ching, only, publicise, lavishly, roscoe,
# Nearest to such: known, these, well, chupacabras, luxuriant, classified, cystitis, realistic,
# Nearest to i: we, ii, you, g, iii, ethnological, carbines, dawson,
# Nearest to not: still, never, also, usually, now, tov, sometimes, almost,
# Nearest to had: has, have, having, was, were, bukovina, took, operationally,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to than: or, much, eastwards, avidly, slightly, chronos, litchfield, hydrate,
# Nearest to was: is, became, were, had, been, has, be, cet,
# Nearest to seven: four, six, nine, eight, five, zero, three, two,
# Nearest to most: more, many, some, particularly, use, meals, nepalese, soundhole,
# Nearest to are: were, is, have, include, multicellular, greeting, bullion, invertible,
# Nearest to only: heapsort, cybernetic, famously, pancakes, no, steed, budge, isotopes,
# Nearest to would: could, will, can, may, must, should, might, cannot,
# Nearest to while: although, when, before, however, among, bjorn, though, metalworking,
# Nearest to people: women, lada, countries, those, men, jews, sepulchre, children,
# Nearest to used: known, considered, called, written, designed, referred, buttstock, held,
# Average loss at step 32000: 2.828257
# Average loss at step 34000: 2.953088
# Average loss at step 36000: 2.946034
# Average loss at step 38000: 2.935249
# Average loss at step 40000: 2.930730
# Nearest to no: any, druyan, abba, intension, roscoe, smolensk, purer, monastics,
# Nearest to such: these, known, well, including, classified, realistic, cystitis, luxuriant,
# Nearest to i: we, ii, g, you, enosis, dawson, iii, ethnological,
# Nearest to not: never, still, usually, now, sometimes, also, easily, ever,
# Nearest to had: have, has, having, was, bukovina, were, saw, pet,
# Nearest to may: can, could, would, might, must, will, should, cannot,
# Nearest to than: but, much, slightly, bearer, litchfield, milligrams, chronos, avidly,
# Nearest to was: is, became, were, had, been, has, becomes, be,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to most: more, many, some, less, particularly, bassoons, trivially, dilated,
# Nearest to are: were, have, is, including, although, hler, include, interwoven,
# Nearest to only: heapsort, famously, first, yet, always, combined, aligning, grandpa,
# Nearest to would: could, will, can, may, must, might, should, cannot,
# Nearest to while: although, but, when, however, though, and, mansfield, among,
# Nearest to people: women, children, men, americans, countries, writers, persons, scientists,
# Nearest to used: known, referred, designed, written, considered, classified, able, found,
# Average loss at step 42000: 2.948548
# Average loss at step 44000: 2.960164
# Average loss at step 46000: 2.910480
# Average loss at step 48000: 2.865419
# Average loss at step 50000: 2.844017
# Nearest to no: any, only, iadb, publicise, druyan, intension, abba, tubes,
# Nearest to such: known, well, these, follows, certain, classified, many, opposed,
# Nearest to i: we, ii, g, you, maradona, iii, cherokee, emeritus,
# Nearest to not: still, never, now, exercised, generally, tov, easily, definitely,
# Nearest to had: has, have, was, having, were, saw, since, pet,
# Nearest to may: can, could, would, might, will, must, should, cannot,
# Nearest to than: or, much, slightly, and, cesium, milligrams, bearer, eastwards,
# Nearest to was: is, became, had, were, has, been, crosstown, confound,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to most: more, many, some, all, particularly, nepalese, less, telegraph,
# Nearest to are: were, have, is, include, those, unheated, although, ung,
# Nearest to only: no, yet, heapsort, famously, budge, vedas, always, drains,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to while: although, when, before, but, though, and, after, however,
# Nearest to people: children, women, men, americans, jews, lada, countries, downward,
# Nearest to used: known, designed, referred, considered, written, held, found, described,
# Average loss at step 52000: 2.884294
# Average loss at step 54000: 2.860113
# Average loss at step 56000: 2.859791
# Average loss at step 58000: 2.753196
# Average loss at step 60000: 2.825988
# Nearest to no: any, another, collaboration, lipids, abba, iadb, intension, asymmetric,
# Nearest to such: known, these, certain, follows, including, classified, well, anodes,
# Nearest to i: we, you, g, ii, dawson, maradona, iii, cherokee,
# Nearest to not: never, still, now, actually, easily, almost, otherwise, nearly,
# Nearest to had: has, have, was, having, were, saw, bukovina, ever,
# Nearest to may: can, should, could, must, might, would, will, cannot,
# Nearest to than: or, eastwards, slightly, fatty, much, like, milligrams, litchfield,
# Nearest to was: is, had, has, became, were, appears, consists, iterations,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Nearest to most: more, many, particularly, some, less, especially, nepalese, trivially,
# Nearest to are: were, is, have, include, including, while, although, spit,
# Nearest to only: info, wildcats, always, cybernetic, typically, yet, normally, never,
# Nearest to would: will, could, can, might, must, may, should, cannot,
# Nearest to while: although, when, though, however, before, but, including, and,
# Nearest to people: women, men, children, americans, jews, lada, others, individuals,
# Nearest to used: known, designed, considered, referred, described, held, called, seen,
# Average loss at step 62000: 2.828129
# Average loss at step 64000: 2.768779
# Average loss at step 66000: 2.766493
# Average loss at step 68000: 2.715350
# Average loss at step 70000: 2.787567
# Nearest to no: any, intension, aggregates, tubes, hugh, nuncio, ninhursag, furs,
# Nearest to such: known, follows, well, regarded, defined, classified, certain, opposed,
# Nearest to i: we, you, ii, they, tycho, iii, dawson, cartridge,
# Nearest to not: never, now, still, easily, always, actually, tov, really,
# Nearest to had: has, have, having, was, were, never, bukovina, ever,
# Nearest to may: might, should, could, must, can, will, would, cannot,
# Nearest to than: slightly, aggregates, eastwards, bearer, much, or, fatty, milligrams,
# Nearest to was: is, became, were, had, has, been, remained, did,
# Nearest to seven: nine, five, six, eight, four, three, zero, two,
# Nearest to most: more, less, some, many, particularly, especially, nepalese, meals,
# Nearest to are: were, include, have, is, including, those, exist, greeting,
# Nearest to only: wildcats, until, necessary, admitted, heapsort, yet, ddrmax, adopted,
# Nearest to would: will, could, might, must, should, can, may, cannot,
# Nearest to while: although, when, though, before, however, including, after, but,
# Nearest to people: children, women, men, americans, persons, jews, countries, individuals,
# Nearest to used: designed, known, referred, allowed, seen, available, able, described,
# Average loss at step 72000: 2.799553
# Average loss at step 74000: 2.646345
# Average loss at step 76000: 2.803884
# Average loss at step 78000: 2.821130
# Average loss at step 80000: 2.781458
# Nearest to no: any, only, intension, abba, asymmetric, aggregates, monastics, tubes,
# Nearest to such: well, known, these, certain, follows, regarded, cited, act,
# Nearest to i: you, we, ii, dawson, they, iii, he, swinburne,
# Nearest to not: never, still, easily, almost, actually, now, always, otherwise,
# Nearest to had: has, have, having, were, was, bukovina, ever, saw,
# Nearest to may: can, might, could, should, must, will, would, cannot,
# Nearest to than: much, or, fatty, bearer, aggregates, eastwards, milligrams, slightly,
# Nearest to was: is, were, became, has, had, becomes, been, be,
# Nearest to seven: six, nine, eight, five, four, three, zero, two,
# Nearest to most: more, many, less, some, particularly, nepalese, several, all,
# Nearest to are: were, have, include, is, including, tend, badajoz, localization,
# Nearest to only: no, typically, wildcats, stinging, vu, yet, normally, heapsort,
# Nearest to would: could, will, might, must, can, should, may, cannot,
# Nearest to while: although, when, though, before, after, despite, but, began,
# Nearest to people: men, children, women, persons, americans, jews, writers, players,
# Nearest to used: known, referred, designed, described, required, able, available, found,
# Average loss at step 82000: 2.666845
# Average loss at step 84000: 2.768035
# Average loss at step 86000: 2.735211
# Average loss at step 88000: 2.751662
# Average loss at step 90000: 2.735417
# Nearest to no: any, another, intension, only, little, asymmetric, appia, maneuvers,
# Nearest to such: well, known, follows, these, themselves, cited, act, powders,
# Nearest to i: we, you, ii, they, iii, dawson, she, maradona,
# Nearest to not: never, now, always, still, rarely, easily, generally, actually,
# Nearest to had: has, have, was, were, having, saw, attempted, presumes,
# Nearest to may: can, might, should, must, could, would, will, cannot,
# Nearest to than: or, much, avidly, bearer, fatty, humayun, aggregates, milligrams,
# Nearest to was: is, has, became, had, kisses, were, becomes, remained,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to most: more, many, less, some, particularly, especially, nepalese, all,
# Nearest to are: were, is, have, include, including, contain, exist, tend,
# Nearest to only: no, until, either, always, normally, even, vu, phosphide,
# Nearest to would: could, will, might, must, can, should, may, cannot,
# Nearest to while: although, when, though, despite, before, however, after, began,
# Nearest to people: women, children, americans, men, persons, scientists, jews, immigrants,
# Nearest to used: described, known, designed, referred, required, sold, found, called,
# Average loss at step 92000: 2.676131
# Average loss at step 94000: 2.728655
# Average loss at step 96000: 2.700873
# Average loss at step 98000: 2.363609
# Average loss at step 100000: 2.401184
# Nearest to no: any, abba, little, maneuvers, intension, only, appia, fused,
# Nearest to such: known, well, these, many, follows, opposed, chupacabras, certain,
# Nearest to i: you, we, ii, they, iii, maradona, dawson, breatharian,
# Nearest to not: never, now, you, tov, easily, actually, really, always,
# Nearest to had: has, have, having, was, saw, were, is, attempted,
# Nearest to may: might, should, must, could, can, will, would, cannot,
# Nearest to than: or, much, fatty, aggregates, dissolved, humayun, lathe, avidly,
# Nearest to was: is, had, became, has, were, seems, been, did,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to most: more, less, many, especially, particularly, gagauz, locale, ump,
# Nearest to are: were, include, have, is, exist, contain, tend, including,
# Nearest to only: until, last, first, herat, unchanged, no, always, burgeoning,
# Nearest to would: could, will, might, must, should, can, may, cannot,
# Nearest to while: although, when, though, but, began, before, despite, after,
# Nearest to people: children, women, men, persons, americans, immigrants, jews, man,
# Nearest to used: referred, known, designed, required, introduced, cited, sold, applied,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
